# %% [markdown]
# # WeatherPy
# ----
#
# Analysis
# 1. In the Southern Hempishere, the closer to the equator you are (0°), the hotter the temperature. However in the Northern Hempisphere, the warmer temperatures occur at 30°-40° latitude. That is where California falls, so I can attest to July being the hot season.
# 2. Cities within latitudes -35°-60° had the highest humidity. There wasn't much difference between hemispheres, both have humidity increase as the temperature rises, but being the most humid in cities closest to 0°.
# 3. There wasn't a strong correlation between either wind speed and latitutde or cloudiness and latitude. The similarity they both share is that cities closest to the equator are more cloudy and windy.

# %%
#pip install citipy

# %%
#pip install scipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
#import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../Instructions/output_data/cities.csv"


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 642

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"

# Build query URL
#query_url = url + "appid=" + weather_api_key + "&q=" + record

# %%
# # Get weather data in order to see JSON object
# weather_response = requests.get(query_url)
# weather_json = weather_response.json()

# # Convert to dataframe
# city_weather_df=pd.DataFrame(weather_response)

# # Get the temperature from the response
# print(f"The weather API responded with: {weather_json}.")
# Out:
# The weather API responded with: {'coord': {'lon': -35.46, 'lat': -5.2}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 294.15, 'feels_like': 296.37, 'temp_min': 294.15, 'temp_max': 294.15, 'pressure': 1014, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 2.1, 'deg': 250}, 'clouds': {'all': 39}, 'dt': 1595656146, 'sys': {'type': 1, 'id': 8452, 'country': 'BR', 'sunrise': 1595665924, 'sunset': 1595708661}, 'timezone': -10800, 'id': 3386213, 'name': 'Touros', 'cod': 200}.

# %%
print(f"Beginning Data Retrieval")
print("-----------------------------")

record_counter=0
set_counter=1

# List to hold city dictionaries
city_list=[]
# 
for city in cities:
    if record_counter==50:
        set_counter+=1
        record_counter=0
    # Build query URL & request temps in F
    query_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=imperial"
    print(f"Processing Record {record_counter} of Set {set_counter} | {city}")
    record_counter+=1
    try: 
        city_response=requests.get(query_url)
        city_data=city_response.json()
        city_maxtemp=city_data["main"]["temp_max"]
        city_humidity=city_data["main"]["humidity"]
        city_cloudiness=city_data["clouds"]["all"]
        city_windspeed=city_data["wind"]["speed"]
        city_country=city_data["sys"]["country"]
        city_date=city_data["dt"]
        city_lat=city_data["coord"]["lat"]
        city_lon=city_data["coord"]["lon"]
        # Create dictionary to hold city data
        weather_dict={"City": city,
                      "Lat": city_lat,
                      "Lon": city_lon,
                      "Max Temp": city_maxtemp,
                      "Humidity": city_humidity,
                      "Cloudiness": city_cloudiness,
                      "Wind Speed": city_windspeed,
                      "Country": city_country,
                      "Date": city_date}
        city_list.append(weather_dict)
    except:
        print("City not found. Skipping...")
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 1 | toora-khem
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | chuy
# Processing Record 4 of Set 1 | uvat
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | baruun-urt
# Processing Record 7 of Set 1 | myitkyina
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | nikolskoye
# Processing Record 10 of Set 1 | new norfolk
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | carnarvon
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | grimshaw
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | komsomolskiy
# Processing Record 17 of Set 1 | ust-nera
# Processing Record 18 of Set 1 | diu
# Processing Record 19 of Set 1 | beni
# Processing Record 20 of Set 1 | kruisfontein
# Processing Record 21 of Set 1 | nipani
# Processing Record 22 of Set 1 | arraial do cabo
# Processing Record 23 of Set 1 | poum
# Processing Record 24 of Set 1 | santa cruz
# Processing Record 25 of Set 1 | port elizabeth
# Processing Record 26 of Set 1 | bluff
# Processing Record 27 of Set 1 | dikson
# Processing Record 28 of Set 1 | lata
# Processing Record 29 of Set 1 | saskylakh
# Processing Record 30 of Set 1 | fortuna
# Processing Record 31 of Set 1 | vila velha
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | pringsewu
# Processing Record 34 of Set 1 | mwinilunga
# Processing Record 35 of Set 1 | bonnyville
# Processing Record 36 of Set 1 | moose factory
# Processing Record 37 of Set 1 | bulaon
# Processing Record 38 of Set 1 | hobart
# Processing Record 39 of Set 1 | shepsi
# Processing Record 40 of Set 1 | aranos
# Processing Record 41 of Set 1 | kichera
# Processing Record 42 of Set 1 | balad
# Processing Record 43 of Set 1 | cherskiy
# Processing Record 44 of Set 1 | milicz
# Processing Record 45 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 1 | luderitz
# Processing Record 47 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 1 | lensk
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 0 of Set 2 | jijiga
# Processing Record 1 of Set 2 | saint anthony
# Processing Record 2 of Set 2 | souillac
# Processing Record 3 of Set 2 | port alfred
# Processing Record 4 of Set 2 | angoche
# Processing Record 5 of Set 2 | turayf
# Processing Record 6 of Set 2 | cooma
# Processing Record 7 of Set 2 | vaini
# Processing Record 8 of Set 2 | buala
# Processing Record 9 of Set 2 | castro
# Processing Record 10 of Set 2 | iqaluit
# Processing Record 11 of Set 2 | beringovskiy
# Processing Record 12 of Set 2 | batagay-alyta
# Processing Record 13 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 2 | ialibu
# Processing Record 15 of Set 2 | guerrero negro
# Processing Record 16 of Set 2 | okha
# Processing Record 17 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 2 | channel-port aux basques
# Processing Record 19 of Set 2 | mutsamudu
# City not found. Skipping...
# Processing Record 20 of Set 2 | kaffrine
# Processing Record 21 of Set 2 | biak
# Processing Record 22 of Set 2 | yulara
# Processing Record 23 of Set 2 | hasaki
# Processing Record 24 of Set 2 | mataura
# Processing Record 25 of Set 2 | pitimbu
# Processing Record 26 of Set 2 | george
# Processing Record 27 of Set 2 | praia da vitoria
# Processing Record 28 of Set 2 | weston
# Processing Record 29 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 2 | thompson
# Processing Record 32 of Set 2 | merauke
# Processing Record 33 of Set 2 | bijar
# Processing Record 34 of Set 2 | nosy varika
# Processing Record 35 of Set 2 | sao gabriel da cachoeira
# Processing Record 36 of Set 2 | bengkulu
# Processing Record 37 of Set 2 | mahebourg
# Processing Record 38 of Set 2 | carutapera
# Processing Record 39 of Set 2 | mount gambier
# Processing Record 40 of Set 2 | hithadhoo
# Processing Record 41 of Set 2 | albany
# Processing Record 42 of Set 2 | gambo
# Processing Record 43 of Set 2 | akyab
# Processing Record 44 of Set 2 | arecibo
# Processing Record 45 of Set 2 | shahr-e babak
# Processing Record 46 of Set 2 | hilo
# Processing Record 47 of Set 2 | mount isa
# Processing Record 48 of Set 2 | kalmunai
# Processing Record 49 of Set 2 | hirado
# Processing Record 0 of Set 3 | xingcheng
# Processing Record 1 of Set 3 | bagaces
# Processing Record 2 of Set 3 | touros
# Processing Record 3 of Set 3 | hambantota
# Processing Record 4 of Set 3 | krasnoselkup
# Processing Record 5 of Set 3 | tiksi
# Processing Record 6 of Set 3 | unye
# City not found. Skipping...
# Processing Record 7 of Set 3 | kodiak
# Processing Record 8 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 3 | udachnyy
# Processing Record 10 of Set 3 | zhigansk
# Processing Record 11 of Set 3 | tilichiki
# Processing Record 12 of Set 3 | kapaa
# Processing Record 13 of Set 3 | salalah
# Processing Record 14 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 3 | saquena
# Processing Record 16 of Set 3 | hermanus
# Processing Record 17 of Set 3 | la primavera
# Processing Record 18 of Set 3 | frechen
# Processing Record 19 of Set 3 | beatrice
# Processing Record 20 of Set 3 | pacific grove
# Processing Record 21 of Set 3 | richards bay
# Processing Record 22 of Set 3 | tasiilaq
# Processing Record 23 of Set 3 | namatanai
# Processing Record 24 of Set 3 | leshukonskoye
# Processing Record 25 of Set 3 | talnakh
# Processing Record 26 of Set 3 | bathsheba
# Processing Record 27 of Set 3 | nova russas
# Processing Record 28 of Set 3 | kendari
# Processing Record 29 of Set 3 | baiyin
# Processing Record 30 of Set 3 | najran
# Processing Record 31 of Set 3 | guatire
# Processing Record 32 of Set 3 | kavieng
# Processing Record 33 of Set 3 | vao
# Processing Record 34 of Set 3 | santa maria
# Processing Record 35 of Set 3 | canutama
# Processing Record 36 of Set 3 | karatuzskoye
# Processing Record 37 of Set 3 | tacoronte
# Processing Record 38 of Set 3 | batagay
# Processing Record 39 of Set 3 | waipawa
# Processing Record 40 of Set 3 | chernyshevskiy
# Processing Record 41 of Set 3 | kojori
# Processing Record 42 of Set 3 | portland
# Processing Record 43 of Set 3 | coquimbo
# Processing Record 44 of Set 3 | ancud
# Processing Record 45 of Set 3 | port hardy
# Processing Record 46 of Set 3 | butaritari
# Processing Record 47 of Set 3 | east london
# Processing Record 48 of Set 3 | alugan
# Processing Record 49 of Set 3 | hamois
# Processing Record 0 of Set 4 | saint-pierre
# Processing Record 1 of Set 4 | salinas
# Processing Record 2 of Set 4 | bandarbeyla
# Processing Record 3 of Set 4 | yellowknife
# Processing Record 4 of Set 4 | sambava
# Processing Record 5 of Set 4 | ilulissat
# Processing Record 6 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 7 of Set 4 | ahipara
# Processing Record 8 of Set 4 | faanui
# Processing Record 9 of Set 4 | deputatskiy
# Processing Record 10 of Set 4 | bethel
# Processing Record 11 of Set 4 | yatou
# Processing Record 12 of Set 4 | sorong
# Processing Record 13 of Set 4 | lagoa
# Processing Record 14 of Set 4 | stornoway
# Processing Record 15 of Set 4 | basco
# Processing Record 16 of Set 4 | puerto ayora
# Processing Record 17 of Set 4 | gangotri
# City not found. Skipping...
# Processing Record 18 of Set 4 | isangel
# Processing Record 19 of Set 4 | mar del plata
# Processing Record 20 of Set 4 | lokoja
# Processing Record 21 of Set 4 | padang
# Processing Record 22 of Set 4 | saint george
# Processing Record 23 of Set 4 | champerico
# Processing Record 24 of Set 4 | bredasdorp
# Processing Record 25 of Set 4 | lavrentiya
# Processing Record 26 of Set 4 | shimoda
# Processing Record 27 of Set 4 | clarence town
# Processing Record 28 of Set 4 | victoria
# Processing Record 29 of Set 4 | airai
# Processing Record 30 of Set 4 | pompeu
# Processing Record 31 of Set 4 | abnub
# Processing Record 32 of Set 4 | cidreira
# Processing Record 33 of Set 4 | clyde river
# Processing Record 34 of Set 4 | rio gallegos
# Processing Record 35 of Set 4 | cape town
# Processing Record 36 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 37 of Set 4 | porto santo
# Processing Record 38 of Set 4 | norman wells
# Processing Record 39 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 4 | buy
# Processing Record 41 of Set 4 | egvekinot
# Processing Record 42 of Set 4 | porto novo
# Processing Record 43 of Set 4 | sedelnikovo
# City not found. Skipping...
# Processing Record 44 of Set 4 | shieli
# Processing Record 45 of Set 4 | tuktoyaktuk
# Processing Record 46 of Set 4 | barrow
# Processing Record 47 of Set 4 | rasskazovo
# Processing Record 48 of Set 4 | hirara
# Processing Record 49 of Set 4 | kaitangata
# Processing Record 0 of Set 5 | arman
# Processing Record 1 of Set 5 | highlands ranch
# Processing Record 2 of Set 5 | kayankulam
# Processing Record 3 of Set 5 | shu
# Processing Record 4 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 5 | caravelas
# Processing Record 6 of Set 5 | georgetown
# Processing Record 7 of Set 5 | bambous virieux
# Processing Record 8 of Set 5 | ozernovskiy
# Processing Record 9 of Set 5 | marsh harbour
# Processing Record 10 of Set 5 | flinders
# Processing Record 11 of Set 5 | vostok
# Processing Record 12 of Set 5 | ribeira grande
# Processing Record 13 of Set 5 | ulfborg
# Processing Record 14 of Set 5 | nakamura
# Processing Record 15 of Set 5 | daru
# Processing Record 16 of Set 5 | college
# Processing Record 17 of Set 5 | da nang
# Processing Record 18 of Set 5 | lesnoy
# Processing Record 19 of Set 5 | nzerekore
# Processing Record 20 of Set 5 | taburi
# City not found. Skipping...
# Processing Record 21 of Set 5 | killarney
# Processing Record 22 of Set 5 | winslow
# Processing Record 23 of Set 5 | mendi
# Processing Record 24 of Set 5 | samarai
# Processing Record 25 of Set 5 | kosh-agach
# Processing Record 26 of Set 5 | hamilton
# Processing Record 27 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 5 | carnduff
# Processing Record 29 of Set 5 | pacifica
# Processing Record 30 of Set 5 | narsaq
# Processing Record 31 of Set 5 | baglung
# Processing Record 32 of Set 5 | saldanha
# Processing Record 33 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 5 | malanje
# Processing Record 35 of Set 5 | pevek
# Processing Record 36 of Set 5 | aksarka
# Processing Record 37 of Set 5 | alibag
# Processing Record 38 of Set 5 | ormara
# Processing Record 39 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 5 | progreso
# Processing Record 41 of Set 5 | umm kaddadah
# Processing Record 42 of Set 5 | yurga
# Processing Record 43 of Set 5 | severo-yeniseyskiy
# Processing Record 44 of Set 5 | vardo
# Processing Record 45 of Set 5 | batticaloa
# Processing Record 46 of Set 5 | la ronge
# Processing Record 47 of Set 5 | saryshagan
# City not found. Skipping...
# Processing Record 48 of Set 5 | saint-philippe
# Processing Record 49 of Set 5 | lasa
# Processing Record 0 of Set 6 | khatanga
# Processing Record 1 of Set 6 | green river
# Processing Record 2 of Set 6 | bani walid
# Processing Record 3 of Set 6 | mayo
# Processing Record 4 of Set 6 | cabo san lucas
# Processing Record 5 of Set 6 | djibo
# Processing Record 6 of Set 6 | baykit
# Processing Record 7 of Set 6 | bilma
# Processing Record 8 of Set 6 | umm lajj
# Processing Record 9 of Set 6 | saint-francois
# Processing Record 10 of Set 6 | oranjemund
# Processing Record 11 of Set 6 | port lincoln
# Processing Record 12 of Set 6 | chernaya kholunitsa
# Processing Record 13 of Set 6 | ondjiva
# Processing Record 14 of Set 6 | sorland
# Processing Record 15 of Set 6 | camana
# Processing Record 16 of Set 6 | calvillo
# Processing Record 17 of Set 6 | comodoro rivadavia
# Processing Record 18 of Set 6 | metsavan
# Processing Record 19 of Set 6 | ostrovnoy
# Processing Record 20 of Set 6 | jianhu
# Processing Record 21 of Set 6 | kupang
# Processing Record 22 of Set 6 | klaksvik
# Processing Record 23 of Set 6 | anloga
# Processing Record 24 of Set 6 | rudbar
# Processing Record 25 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 6 | thinadhoo
# Processing Record 27 of Set 6 | karratha
# Processing Record 28 of Set 6 | evanston
# Processing Record 29 of Set 6 | upernavik
# Processing Record 30 of Set 6 | hami
# Processing Record 31 of Set 6 | axim
# Processing Record 32 of Set 6 | waitara
# Processing Record 33 of Set 6 | kalemie
# Processing Record 34 of Set 6 | san policarpo
# Processing Record 35 of Set 6 | bagan
# Processing Record 36 of Set 6 | san ignacio
# Processing Record 37 of Set 6 | davila
# Processing Record 38 of Set 6 | okhotsk
# Processing Record 39 of Set 6 | el balyana
# City not found. Skipping...
# Processing Record 40 of Set 6 | mahon
# Processing Record 41 of Set 6 | kyren
# Processing Record 42 of Set 6 | altos
# Processing Record 43 of Set 6 | novobirilyussy
# Processing Record 44 of Set 6 | gari
# Processing Record 45 of Set 6 | juneau
# Processing Record 46 of Set 6 | arlit
# Processing Record 47 of Set 6 | yerbogachen
# Processing Record 48 of Set 6 | grindavik
# Processing Record 49 of Set 6 | davidson
# Processing Record 0 of Set 7 | severo-kurilsk
# Processing Record 1 of Set 7 | grand-santi
# Processing Record 2 of Set 7 | hauterive
# Processing Record 3 of Set 7 | barra patuca
# Processing Record 4 of Set 7 | kulhudhuffushi
# Processing Record 5 of Set 7 | rognan
# Processing Record 6 of Set 7 | mehamn
# Processing Record 7 of Set 7 | cremona
# Processing Record 8 of Set 7 | quirinopolis
# Processing Record 9 of Set 7 | hailar
# Processing Record 10 of Set 7 | totness
# Processing Record 11 of Set 7 | olot
# Processing Record 12 of Set 7 | naze
# Processing Record 13 of Set 7 | grand-lahou
# Processing Record 14 of Set 7 | kawana waters
# City not found. Skipping...
# Processing Record 15 of Set 7 | geraldton
# Processing Record 16 of Set 7 | osa
# Processing Record 17 of Set 7 | idlib
# Processing Record 18 of Set 7 | de-kastri
# Processing Record 19 of Set 7 | capitao poco
# Processing Record 20 of Set 7 | tarskoye
# Processing Record 21 of Set 7 | sile
# Processing Record 22 of Set 7 | antalaha
# Processing Record 23 of Set 7 | kauhajoki
# Processing Record 24 of Set 7 | lebu
# Processing Record 25 of Set 7 | sennoy
# Processing Record 26 of Set 7 | blackpool
# Processing Record 27 of Set 7 | camacupa
# Processing Record 28 of Set 7 | pontal do parana
# Processing Record 29 of Set 7 | nouakchott
# Processing Record 30 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 31 of Set 7 | sukhumi
# Processing Record 32 of Set 7 | saint-georges
# Processing Record 33 of Set 7 | hofn
# Processing Record 34 of Set 7 | hojai
# Processing Record 35 of Set 7 | verkhnyaya toyma
# Processing Record 36 of Set 7 | baihar
# Processing Record 37 of Set 7 | katsuura
# Processing Record 38 of Set 7 | ye
# City not found. Skipping...
# Processing Record 39 of Set 7 | kholodnyy
# Processing Record 40 of Set 7 | north battleford
# Processing Record 41 of Set 7 | sabha
# Processing Record 42 of Set 7 | japura
# Processing Record 43 of Set 7 | florianopolis
# Processing Record 44 of Set 7 | anadyr
# Processing Record 45 of Set 7 | sinnamary
# Processing Record 46 of Set 7 | charters towers
# Processing Record 47 of Set 7 | shelburne
# Processing Record 48 of Set 7 | nhulunbuy
# Processing Record 49 of Set 7 | tawang
# Processing Record 0 of Set 8 | bethanien
# Processing Record 1 of Set 8 | quatre cocos
# Processing Record 2 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 8 | powell
# Processing Record 4 of Set 8 | balingasay
# Processing Record 5 of Set 8 | coralville
# Processing Record 6 of Set 8 | sao joao da barra
# Processing Record 7 of Set 8 | litovko
# Processing Record 8 of Set 8 | ouallam
# Processing Record 9 of Set 8 | waverly
# Processing Record 10 of Set 8 | serenje
# Processing Record 11 of Set 8 | trondheim
# Processing Record 12 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 8 | nizhniy baskunchak
# Processing Record 15 of Set 8 | yar-sale
# Processing Record 16 of Set 8 | tricase
# Processing Record 17 of Set 8 | tiarei
# Processing Record 18 of Set 8 | ponta do sol
# Processing Record 19 of Set 8 | provideniya
# Processing Record 20 of Set 8 | eskasem
# City not found. Skipping...
# Processing Record 21 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 22 of Set 8 | mareeba
# Processing Record 23 of Set 8 | verkhnyaya inta
# Processing Record 24 of Set 8 | yarega
# Processing Record 25 of Set 8 | ibra
# Processing Record 26 of Set 8 | belyy yar
# Processing Record 27 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 8 | san patricio
# Processing Record 29 of Set 8 | atasu
# Processing Record 30 of Set 8 | fort nelson
# Processing Record 31 of Set 8 | kailua
# Processing Record 32 of Set 8 | rio grande
# Processing Record 33 of Set 8 | mancio lima
# Processing Record 34 of Set 8 | mayumba
# Processing Record 35 of Set 8 | porbandar
# Processing Record 36 of Set 8 | alice springs
# Processing Record 37 of Set 8 | kahului
# Processing Record 38 of Set 8 | shitkino
# Processing Record 39 of Set 8 | raudeberg
# Processing Record 40 of Set 8 | yenagoa
# Processing Record 41 of Set 8 | micoud
# Processing Record 42 of Set 8 | laguna
# Processing Record 43 of Set 8 | gat
# Processing Record 44 of Set 8 | miri
# Processing Record 45 of Set 8 | isiro
# Processing Record 46 of Set 8 | vicar
# Processing Record 47 of Set 8 | tadine
# Processing Record 48 of Set 8 | shenjiamen
# Processing Record 49 of Set 8 | boueni
# Processing Record 0 of Set 9 | koulamoutou
# Processing Record 1 of Set 9 | torbay
# Processing Record 2 of Set 9 | cariamanga
# Processing Record 3 of Set 9 | galeana
# Processing Record 4 of Set 9 | kozhevnikovo
# Processing Record 5 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 6 of Set 9 | kota belud
# Processing Record 7 of Set 9 | pangnirtung
# Processing Record 8 of Set 9 | pafos
# Processing Record 9 of Set 9 | celestun
# Processing Record 10 of Set 9 | sitka
# Processing Record 11 of Set 9 | mirandela
# Processing Record 12 of Set 9 | usinsk
# Processing Record 13 of Set 9 | esil
# Processing Record 14 of Set 9 | mikuni
# Processing Record 15 of Set 9 | kaz
# Processing Record 16 of Set 9 | montesarchio
# Processing Record 17 of Set 9 | maceio
# Processing Record 18 of Set 9 | grand gaube
# Processing Record 19 of Set 9 | chateauroux
# Processing Record 20 of Set 9 | nantucket
# Processing Record 21 of Set 9 | jiwani
# Processing Record 22 of Set 9 | nishihara
# Processing Record 23 of Set 9 | chambersburg
# Processing Record 24 of Set 9 | valenca do piaui
# Processing Record 25 of Set 9 | ankazobe
# Processing Record 26 of Set 9 | chimbote
# Processing Record 27 of Set 9 | pilot butte
# Processing Record 28 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 30 of Set 9 | rawson
# Processing Record 31 of Set 9 | tamandare
# Processing Record 32 of Set 9 | lompoc
# Processing Record 33 of Set 9 | kaliua
# Processing Record 34 of Set 9 | imbituba
# Processing Record 35 of Set 9 | huilong
# Processing Record 36 of Set 9 | tchollire
# Processing Record 37 of Set 9 | chupei
# City not found. Skipping...
# Processing Record 38 of Set 9 | gizo
# Processing Record 39 of Set 9 | areosa
# Processing Record 40 of Set 9 | saint-ambroise
# Processing Record 41 of Set 9 | chicama
# Processing Record 42 of Set 9 | yumen
# Processing Record 43 of Set 9 | srednekolymsk
# Processing Record 44 of Set 9 | turbat
# Processing Record 45 of Set 9 | jieshi
# Processing Record 46 of Set 9 | ossora
# Processing Record 47 of Set 9 | road town
# Processing Record 48 of Set 9 | rajshahi
# Processing Record 49 of Set 9 | acarau
# Processing Record 0 of Set 10 | kabompo
# Processing Record 1 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 2 of Set 10 | champasak
# Processing Record 3 of Set 10 | tura
# Processing Record 4 of Set 10 | maningrida
# Processing Record 5 of Set 10 | camacha
# Processing Record 6 of Set 10 | tessalit
# Processing Record 7 of Set 10 | makaleng
# Processing Record 8 of Set 10 | roma
# Processing Record 9 of Set 10 | cockburn town
# Processing Record 10 of Set 10 | molepolole
# Processing Record 11 of Set 10 | longyearbyen
# Processing Record 12 of Set 10 | wajir
# Processing Record 13 of Set 10 | inirida
# Processing Record 14 of Set 10 | peleduy
# Processing Record 15 of Set 10 | puerto escondido
# Processing Record 16 of Set 10 | tezu
# Processing Record 17 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 18 of Set 10 | cayenne
# Processing Record 19 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 10 | huarmey
# Processing Record 21 of Set 10 | bathurst
# Processing Record 22 of Set 10 | acapulco
# Processing Record 23 of Set 10 | naryan-mar
# Processing Record 24 of Set 10 | san andres
# Processing Record 25 of Set 10 | freeport
# Processing Record 26 of Set 10 | candolim
# Processing Record 27 of Set 10 | korla
# Processing Record 28 of Set 10 | viedma
# Processing Record 29 of Set 10 | manokwari
# Processing Record 30 of Set 10 | naifaru
# Processing Record 31 of Set 10 | abong mbang
# Processing Record 32 of Set 10 | nampula
# Processing Record 33 of Set 10 | eureka
# Processing Record 34 of Set 10 | golden
# Processing Record 35 of Set 10 | alofi
# Processing Record 36 of Set 10 | safaga
# Processing Record 37 of Set 10 | muros
# Processing Record 38 of Set 10 | jasper
# Processing Record 39 of Set 10 | mudon
# Processing Record 40 of Set 10 | chokurdakh
# Processing Record 41 of Set 10 | port hedland
# Processing Record 42 of Set 10 | port-cartier
# Processing Record 43 of Set 10 | riyadh
# Processing Record 44 of Set 10 | ginda
# Processing Record 45 of Set 10 | saurimo
# Processing Record 46 of Set 10 | urengoy
# Processing Record 47 of Set 10 | hualmay
# Processing Record 48 of Set 10 | zhangjiakou
# Processing Record 49 of Set 10 | inhambane
# Processing Record 0 of Set 11 | port blair
# Processing Record 1 of Set 11 | ulladulla
# Processing Record 2 of Set 11 | aksu
# Processing Record 3 of Set 11 | matucana
# Processing Record 4 of Set 11 | san felipe
# Processing Record 5 of Set 11 | sampit
# Processing Record 6 of Set 11 | kununurra
# Processing Record 7 of Set 11 | krasnoarmeysk
# Processing Record 8 of Set 11 | havre-saint-pierre
# Processing Record 9 of Set 11 | ergani
# Processing Record 10 of Set 11 | vila franca do campo
# Processing Record 11 of Set 11 | mogadouro
# Processing Record 12 of Set 11 | kangalassy
# Processing Record 13 of Set 11 | mongo
# Processing Record 14 of Set 11 | devonport
# Processing Record 15 of Set 11 | parana
# Processing Record 16 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 17 of Set 11 | coolum beach
# Processing Record 18 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 19 of Set 11 | ballangen
# Processing Record 20 of Set 11 | mahajanga
# Processing Record 21 of Set 11 | rengo
# Processing Record 22 of Set 11 | pundaguitan
# Processing Record 23 of Set 11 | olafsvik
# Processing Record 24 of Set 11 | san quintin
# Processing Record 25 of Set 11 | nouadhibou
# Processing Record 26 of Set 11 | aketi
# Processing Record 27 of Set 11 | guarapari
# Processing Record 28 of Set 11 | perelyub
# Processing Record 29 of Set 11 | tuatapere
# Processing Record 30 of Set 11 | constitucion
# Processing Record 31 of Set 11 | talara
# Processing Record 32 of Set 11 | bud
# Processing Record 33 of Set 11 | vestmannaeyjar
# Processing Record 34 of Set 11 | bosaso
# Processing Record 35 of Set 11 | aswan
# Processing Record 36 of Set 11 | kingsville
# Processing Record 37 of Set 11 | rabo de peixe
# Processing Record 38 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 39 of Set 11 | esperance
# Processing Record 40 of Set 11 | elk river
# Processing Record 41 of Set 11 | barranca
# Processing Record 42 of Set 11 | kashi
# Processing Record 43 of Set 11 | mandan
# Processing Record 44 of Set 11 | jahrom
# City not found. Skipping...
# Processing Record 45 of Set 11 | zyryanka
# Processing Record 46 of Set 11 | dillon
# Processing Record 47 of Set 11 | sandnessjoen
# Processing Record 48 of Set 11 | qaqortoq
# Processing Record 49 of Set 11 | barabai
# Processing Record 0 of Set 12 | mackenzie
# Processing Record 1 of Set 12 | argir
# Processing Record 2 of Set 12 | balimo
# City not found. Skipping...
# Processing Record 3 of Set 12 | codrington
# Processing Record 4 of Set 12 | urman
# Processing Record 5 of Set 12 | vilyuysk
# Processing Record 6 of Set 12 | suez
# Processing Record 7 of Set 12 | peniche
# Processing Record 8 of Set 12 | lamu
# Processing Record 9 of Set 12 | sibolga
# Processing Record 10 of Set 12 | buckeye
# Processing Record 11 of Set 12 | halifax
# Processing Record 12 of Set 12 | itarema
# Processing Record 13 of Set 12 | tarabuco
# Processing Record 14 of Set 12 | port-gentil
# Processing Record 15 of Set 12 | kamenka
# Processing Record 16 of Set 12 | nalvo
# Processing Record 17 of Set 12 | voh
# Processing Record 18 of Set 12 | broome
# Processing Record 19 of Set 12 | coihaique
# Processing Record 20 of Set 12 | boa vista
# Processing Record 21 of Set 12 | ambilobe
# Processing Record 22 of Set 12 | ostersund
# Processing Record 23 of Set 12 | coahuayana
# Processing Record 24 of Set 12 | kemijarvi
# Processing Record 25 of Set 12 | bolonchen
# City not found. Skipping...
# Processing Record 26 of Set 12 | wajima
# Processing Record 27 of Set 12 | aklavik
# Processing Record 28 of Set 12 | vilkija
# Processing Record 29 of Set 12 | pochutla
# Processing Record 30 of Set 12 | privas
# Processing Record 31 of Set 12 | ewing
# Processing Record 32 of Set 12 | dudinka
# Processing Record 33 of Set 12 | pedernales
# Processing Record 34 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 35 of Set 12 | kibre mengist
# Processing Record 36 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 12 | havelock
# Processing Record 38 of Set 12 | termiz
# Processing Record 39 of Set 12 | norrtalje
# Processing Record 40 of Set 12 | chapais
# Processing Record 41 of Set 12 | kaeo
# Processing Record 42 of Set 12 | zeya
# Processing Record 43 of Set 12 | auki
# Processing Record 44 of Set 12 | casian
# Processing Record 45 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 46 of Set 12 | toppenish
# Processing Record 47 of Set 12 | mandalgovi
# Processing Record 48 of Set 12 | meulaboh
# Processing Record 49 of Set 12 | soligalich
# Processing Record 0 of Set 13 | lethem
# Processing Record 1 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 2 of Set 13 | benguela
# Processing Record 3 of Set 13 | la palma
# Processing Record 4 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 5 of Set 13 | itupiranga
# Processing Record 6 of Set 13 | deniliquin
# Processing Record 7 of Set 13 | port macquarie
# Processing Record 8 of Set 13 | narvacan
# Processing Record 9 of Set 13 | greystones
# Processing Record 10 of Set 13 | nisia floresta
# Processing Record 11 of Set 13 | carahue
# Processing Record 12 of Set 13 | palu
# Processing Record 13 of Set 13 | gornja radgona
# Processing Record 14 of Set 13 | chaman
# Processing Record 15 of Set 13 | aleysk
# Processing Record 16 of Set 13 | shelabolikha
# Processing Record 17 of Set 13 | pyay
# Processing Record 18 of Set 13 | sakakah
# Processing Record 19 of Set 13 | vanderhoof
# Processing Record 20 of Set 13 | ulcinj
# Processing Record 21 of Set 13 | tamara
# Processing Record 22 of Set 13 | jerantut
# Processing Record 23 of Set 13 | labuhan
# Processing Record 24 of Set 13 | bonavista
# Processing Record 25 of Set 13 | cochrane
# Processing Record 26 of Set 13 | shihezi
# Processing Record 27 of Set 13 | gamba
# Processing Record 28 of Set 13 | boyabat
# Processing Record 29 of Set 13 | avera
# Processing Record 30 of Set 13 | santa helena
# Processing Record 31 of Set 13 | presidente epitacio
# Processing Record 32 of Set 13 | payson
# Processing Record 33 of Set 13 | bambanglipuro
# Processing Record 34 of Set 13 | horodyshche
# Processing Record 35 of Set 13 | dunayivtsi
# City not found. Skipping...
# Processing Record 36 of Set 13 | koksovyy
# Processing Record 37 of Set 13 | frutal
# Processing Record 38 of Set 13 | fairbanks
# Processing Record 39 of Set 13 | kampot
# Processing Record 40 of Set 13 | faya
# Processing Record 41 of Set 13 | bilbor
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert city_list to a new dataframe
cities_weather_df=pd.DataFrame(city_list)

# Save cities_weather_df to CSV 
cities_weather_df.to_csv("City Weather Data.csv", encoding="utf-8", index=False)

# %%
cities_weather_df.head()
# Out:
#          City    Lat     Lon  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  toora-khem  52.47   96.11     48.96        81          50        0.92
# 1      atuona  -9.80 -139.03     79.63        71           1       25.23
# 2        chuy -33.70  -53.46     50.22        86          52        6.15
# 3        uvat  59.14   68.90     44.22        82          46        5.21
# 4     qaanaaq  77.48  -69.36     46.17        57          76        3.15
#
#   Country        Date
# 0      RU  1595892065
# 1      PF  1595892065
# 2      UY  1595892065
# 3      RU  1595892065
# 4      GL  1595891852

# %%
# Out:
# City          550
# Lat           550
# Lng           550
# Max Temp      550
# Humidity      550
# Cloudiness    550
# Wind Speed    550
# Country       550
# Date          550
# dtype: int64

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Sort by humidity to find if there are values >100%
cities_lowhumidity=cities_weather_df.sort_values(by=["Humidity"], ascending=True)
cities_lowhumidity.head()
# Out:
#              City    Lat     Lon  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 543          kaeo -35.10  173.78     63.00         3          98        8.99
# 515       buckeye  33.37 -112.58    111.20        12           0        4.70
# 159  saint george  37.10 -113.58    102.99        13           1       13.87
# 567       sakakah  29.97   40.21     95.00        15           3        6.93
# 493         aswan  24.09   32.91     91.15        15          24        7.94
#
#     Country        Date
# 543      NZ  1595892177
# 515      US  1595891907
# 159      US  1595892097
# 567      SA  1595892182
# 493      EG  1595892166

# %%
# # Drop cities with humidity >100%
# cities_highhumidity=cities_lowhumidity.loc[cities_lowhumidity["Humidity"]>100]

# cities_highhumidity.head()

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#        City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  pimentel  -6.84  -79.93     66.20        29          75        5.82
# 1  victoria  22.29  114.16     69.01        88          40       18.34
# 2    padang  -0.95  100.35     79.90        75          99        1.63
# 3    hasaki  35.73  140.83     55.00       100          75        4.70
# 4   kahului  20.89 -156.47     70.00        88           1        7.63
#
#   Country        Date
# 0      PE  1585764415
# 1      HK  1585764288
# 2      ID  1585764115
# 3      JP  1585764415
# 4      US  1585764415

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build latitude vs max temp scatter plot
plt.scatter(cities_weather_df["Lat"], cities_weather_df["Max Temp"], marker="o", edgecolors="black", c="blue")

# Incorporate the other graph properties
plt.title("City Latitude vs Max Temperature (07/27/20)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build latitude vs humidity scatter plot
plt.scatter(cities_weather_df["Lat"], cities_weather_df["Humidity"], marker="o", edgecolors="black", c="blue")

# Incorporate the other graph properties
plt.title("City Latitude vs Humidity (07/27/20)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build latitude vs cloudiness scatter plot
plt.scatter(cities_weather_df["Lat"], cities_weather_df["Cloudiness"], marker="o", edgecolors="black", c="blue")

# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness (07/27/20)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build latitude vs wind speed scatter plot
plt.scatter(cities_weather_df["Lat"], cities_weather_df["Wind Speed"], marker="o", edgecolors="black", c="blue")

# Incorporate the other graph properties
plt.title("City Latitude vs Wind Speed (07/27/20)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern Hemisphere DataFrame
cities_northern_hem=cities_weather_df.loc[cities_weather_df["Lat"]>0]
cities_northern_hem.head()
# Out:
#          City    Lat     Lon  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  toora-khem  52.47   96.11     48.96        81          50        0.92
# 3        uvat  59.14   68.90     44.22        82          46        5.21
# 4     qaanaaq  77.48  -69.36     46.17        57          76        3.15
# 5  baruun-urt  46.68  113.28     60.84        82           2       11.39
# 6   myitkyina  25.38   97.40     73.80        96          78        1.12
#
#   Country        Date
# 0      RU  1595892065
# 3      RU  1595892065
# 4      GL  1595891852
# 5      MN  1595892066
# 6      MM  1595892066

# %%
# Create Southern Hemisphere DataFrame
cities_southern_hem=cities_weather_df.loc[cities_weather_df["Lat"]<0]
cities_southern_hem.head()
# Out:
#            City    Lat     Lon  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 1        atuona  -9.80 -139.03     79.63        71           1       25.23
# 2          chuy -33.70  -53.46     50.22        86          52        6.15
# 7       ushuaia -54.80  -68.30     33.80        80          40       20.80
# 9   new norfolk -42.78  147.06     46.00        92          46        1.34
# 10    busselton -33.65  115.33     46.99        98           2        7.85
#
#    Country        Date
# 1       PF  1595892065
# 2       UY  1595892065
# 7       AR  1595892066
# 9       AU  1595892066
# 10      AU  1595892067

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Calculate the linear regression
x_values=cities_northern_hem["Lat"]
y_values=cities_northern_hem["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

# Save the figure
plt.savefig("NorthernHem Max Temp v Lat.png")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.4318382633281913

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Calculate the linear regression
x_values=cities_southern_hem["Lat"]
y_values=cities_southern_hem["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

# Save the figure
plt.savefig("SouthernHem Max Temp v Lat.png")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.6266535500374952

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Calculate the linear regression
x_values=cities_northern_hem["Lat"]
y_values=cities_northern_hem["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Save the figure
plt.savefig("NorthernHem Humidity v Lat.png")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.008874101929486643

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Calculate the linear regression
x_values=cities_southern_hem["Lat"]
y_values=cities_southern_hem["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Save the figure
plt.savefig("SouthernHem Humidity v Lat.png")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00011142230231437707

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Calculate the linear regression
x_values=cities_northern_hem["Lat"]
y_values=cities_northern_hem["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

# Save the figure
plt.savefig("NorthernHem Cloudiness v Lat.png")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.015577798596959899

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Calculate the linear regression
x_values=cities_southern_hem["Lat"]
y_values=cities_southern_hem["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

# Save the figure
plt.savefig("SouthernHem Cloudiness v Lat.png")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 9.839120411435141e-05

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Calculate the linear regression
x_values=cities_northern_hem["Lat"]
y_values=cities_northern_hem["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

# Save the figure
plt.savefig("NorthernHem Wind v Lat.png")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0002890343546761443

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Calculate the linear regression
x_values=cities_southern_hem["Lat"]
y_values=cities_southern_hem["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

# Save the figure
plt.savefig("SouthernHem Wind v Lat.png")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.008468781354314624
